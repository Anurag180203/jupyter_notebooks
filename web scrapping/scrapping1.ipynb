# %%
import requests
from tqdm import tqdm
import pandas as pd
from bs4 import BeautifulSoup
import os 
import locale  
os.environ["PYTHONIOENCODING"] = "utf-8"
myLocale=locale.setlocale(category=locale.LC_ALL, locale="en_GB.UTF-8")
link = 'http://quotes.toscrape.com/'
page = requests.get(link)
page
# Out:
# <Response [200]>

# %%
html = page.text
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
fd = open('main.html','w')
fd.write(str(html.encode('utf-8').strip()).replace('\\n','\n'))
fd.close()

# %%
soup = BeautifulSoup(html,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
# ...

# %%
soup.find('span',class_='text').text[1:-1]
# Out:
# 'The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.'

# %%
list_of_quotes = []
for i in soup.find_all('span',class_='text'):
    list_of_quotes.append(i.text[1:-1])
list_of_quotes
# Out:
# ['The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.',
#  'It is our choices, Harry, that show what we truly are, far more than our abilities.',
#  'There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.',
#  'The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.',
#  "Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.",
#  'Try not to become a man of success. Rather become a man of value.',
#  'It is better to be hated for what you are than to be loved for what you are not.',
#  "I have not failed. I've just found 10,000 ways that won't work.",
#  "A woman is like a tea bag; you never know how strong it is until it's in hot water.",
#  'A day without sunshine is like, you know, night.']

# %%
data = []
for sp in soup.find_all('div',class_='quote'):
    quote = sp.find('span',class_='text').text[1:-1]
    author = sp.find('small',class_='author').text
    author_id = sp.find('a').get('href')
    tags = sp.find('div',class_='tags').find_all('a',class_='tag')
    tags = ','.join([i.text for i in tags])
    print(quote,author,author_id,tags,sep='\n')
    print()
    data.append([quote,author,author_id,tags])
print(data.__len__())
# Out:
# The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.
# Albert Einstein
# /author/Albert-Einstein
# change,deep-thoughts,thinking,world
#
# It is our choices, Harry, that show what we truly are, far more than our abilities.
# J.K. Rowling
# /author/J-K-Rowling
# abilities,choices
#
# There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.
# Albert Einstein
# /author/Albert-Einstein
# inspirational,life,live,miracle,miracles
#
# The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.
# Jane Austen
# /author/Jane-Austen
# aliteracy,books,classic,humor
#
# Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.
# Marilyn Monroe
# /author/Marilyn-Monroe
# be-yourself,inspirational
#
# Try not to become a man of success. Rather become a man of value.
# ...

# %%
df = pd.DataFrame(data,columns=['quote','author','author_id','tags'])
df
# Out:
#                                                quote             author  \
# 0  The world as we have created it is a process o...    Albert Einstein
# 1  It is our choices, Harry, that show what we tr...       J.K. Rowling
# 2  There are only two ways to live your life. One...    Albert Einstein
# 3  The person, be it gentleman or lady, who has n...        Jane Austen
# 4  Imperfection is beauty, madness is genius and ...     Marilyn Monroe
# 5  Try not to become a man of success. Rather bec...    Albert Einstein
# 6  It is better to be hated for what you are than...         André Gide
# 7  I have not failed. I've just found 10,000 ways...   Thomas A. Edison
# 8  A woman is like a tea bag; you never know how ...  Eleanor Roosevelt
# 9   A day without sunshine is like, you know, night.       Steve Martin
#
#                    author_id                                      tags
# 0    /author/Albert-Einstein       change,deep-thoughts,thinking,world
# ...

# %%
df.to_csv('quotes.csv',index=False)

# %%
data = []
for page in tqdm(range(1,11)):
    link = "https://quotes.toscrape.com/page/"+str(page)+"/"
    page = requests.get(link)
    soup = BeautifulSoup(page.text,'html.parser')
    for sp in soup.find_all('div',class_='quote'):
        quote = sp.find('span',class_='text').text[1:-1]
        author = sp.find('small',class_='author').text
        author_id = sp.find('a').get('href')
        tags = sp.find('div',class_='tags').find_all('a',class_='tag')
        tags = ','.join([i.text for i in tags])
        data.append([quote,author,author_id,tags])
# Out:
# 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]

# %%
df = pd.DataFrame(data,columns=['quote','author','author_id','tags'])
df.to_csv('quotes.csv',index=False)

# %%
author_df = pd.read_csv('quotes.csv')
del author_df['quote']
del author_df['tags']
author_df = author_df.drop_duplicates()
author_df['author_id'] = 'http://quotes.toscrape.com/'[:-1] + author_df['author_id'] 
author_df
# Out:
#                     author                                          author_id
# 0          Albert Einstein  http://quotes.toscrape.com/author/Albert-Einstein
# 1             J.K. Rowling      http://quotes.toscrape.com/author/J-K-Rowling
# 3              Jane Austen      http://quotes.toscrape.com/author/Jane-Austen
# 4           Marilyn Monroe   http://quotes.toscrape.com/author/Marilyn-Monroe
# 6               André Gide       http://quotes.toscrape.com/author/Andre-Gide
# 7         Thomas A. Edison  http://quotes.toscrape.com/author/Thomas-A-Edison
# 8        Eleanor Roosevelt  http://quotes.toscrape.com/author/Eleanor-Roos...
# 9             Steve Martin     http://quotes.toscrape.com/author/Steve-Martin
# 13              Bob Marley       http://quotes.toscrape.com/author/Bob-Marley
# 14               Dr. Seuss         http://quotes.toscrape.com/author/Dr-Seuss
# 15           Douglas Adams    http://quotes.toscrape.com/author/Douglas-Adams
# ...

# %%
data = []
for author in tqdm(author_df.values):
    name = 'Authors/'+author[0]+'.txt'
    link = author[1]
    page = requests.get(link)
    soup = BeautifulSoup(page.text,'html.parser')
    text = soup.find('div',class_='author-details').text.encode('utf-8', errors='ignore')
    data.append(text.strip())
    fd = open(name,'w')
    fd.write(str(text))
    fd.close()
# Out:
# 100%|██████████| 50/50 [00:56<00:00,  1.13s/it]

# %%
author_df['author_info'] = data
author_df.to_csv('author_info.csv',index=False)
